# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

# %%
bar = (
    Bar(opts.InitOpts(js_host="https://cdn.kesci.com/lib/pyecharts_assets/"))
    .add_xaxis(["衬衫", "毛衣", "领带", "裤子", "风衣", "高跟鞋", "袜子"])
    .add_yaxis("商家A", [114, 55, 27, 101, 125, 27, 105])
    .add_yaxis("商家B", [57, 134, 137, 129, 145, 60, 49])
    .set_global_opts(
        datazoom_opts=[opts.DataZoomOpts(is_show=True)],
        title_opts=opts.TitleOpts(title="某商场销售情况")
    )
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://cdn.kesci.com/lib/pyecharts_assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c2de10b9423b4153aa8c29bacc14f894" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c2de10b9423b4153aa8c29bacc14f894 = echarts.init(
#                     document.getElementById('c2de10b9423b4153aa8c29bacc14f894'), 'white', {renderer: 'canvas'});
#                 var option_c2de10b9423b4153aa8c29bacc14f894 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
from pyecharts import options as opts
from pyecharts.globals import ThemeType
from pyecharts.charts import Bar

# %%
v1 = [5, 20, 36, 10, 75, 90]
v2 = [10, 25, 8, 60, 20, 80]
x = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]

# %%
bar = (
    Bar(opts.InitOpts(width = '1000px',height = '500px',theme=ThemeType.INFOGRAPHIC))
    .add_xaxis(x)
    .add_yaxis("商家A", v1,is_selected = True)
    .add_yaxis("商家B", v2,is_selected = True)
    .set_global_opts(
            # 设置全局参数
            title_opts = opts.TitleOpts(title="商场数据显示"), # 设置title
            xaxis_opts= opts.AxisOpts(
                splitline_opts=opts.SplitLineOpts(is_show=True)
                ),  # 设置x轴
            yaxis_opts= opts.AxisOpts(
                splitarea_opts=opts.SplitAreaOpts(is_show=True, areastyle_opts=opts.AreaStyleOpts(opacity=1))
                ),  # 设置y轴
            toolbox_opts = opts.ToolboxOpts(is_show = True),  # 设置工具箱
            datazoom_opts= [opts.DataZoomOpts(range_start=10, range_end=80,is_zoom_lock=False)],   # 设置slider
        )
    .set_series_opts(
            # 设置系列配置
            markpoint_opts=opts.MarkPointOpts(
                data=[
                    opts.MarkPointItem(type_="max", name="最大值"),
                    opts.MarkPointItem(type_="min", name="最小值"),
                ]
            ),
            markline_opts=opts.MarkLineOpts(
                data=[
                    opts.MarkLineItem(type_="average", name="平均值"),
                ]
            ),
        )
    )

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'infographic':'https://assets.pyecharts.org/assets/themes/infographic'
#         }
#     });
# </script>
#
#         <div id="28063a694eb342c2bf65a42156b77ad3" style="width:1000px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'infographic'], function(echarts) {
#                 var chart_28063a694eb342c2bf65a42156b77ad3 = echarts.init(
#                     document.getElementById('28063a694eb342c2bf65a42156b77ad3'), 'infographic', {renderer: 'canvas'});
#                 var option_28063a694eb342c2bf65a42156b77ad3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
# ...

# %%
from pyecharts.charts import Line

line = (
    Line(opts.InitOpts(width = '1000px',height = '500px'))
    .add_xaxis(x)
    .add_yaxis("商家A", v1,is_selected = True,is_smooth=True)
    .add_yaxis("商家B", v2,is_selected = True,is_step=True)
    )

line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2c0242673e924b0685c3f5b42c4dd0c5" style="width:1000px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2c0242673e924b0685c3f5b42c4dd0c5 = echarts.init(
#                     document.getElementById('2c0242673e924b0685c3f5b42c4dd0c5'), 'white', {renderer: 'canvas'});
#                 var option_2c0242673e924b0685c3f5b42c4dd0c5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
# 散点图
from pyecharts.charts import Scatter
from pyecharts.charts import EffectScatter
from pyecharts.globals import SymbolType
    # 标记样式

sca1 = (
    Scatter(opts.InitOpts(width = '1000px',height = '500px'))
    .add_xaxis(x)
    .add_yaxis("商家A", v1,is_selected = True)
    .add_yaxis("商家B", v2,is_selected = True)
    .set_global_opts(
            visualmap_opts=opts.VisualMapOpts(type_="size", max_=150, min_=20)  #  # 映射过渡类型，可选，"color", "size"
        )
    )
sca2 = (
    EffectScatter(opts.InitOpts(width = '1000px',height = '500px'))
    .add_xaxis(x)
    .add_yaxis("商家A", v1,is_selected = True,symbol_size = 10, symbol=SymbolType.ARROW)
        # 'circle', 'rect', 'roundRect', 'triangle','diamond', 'pin', 'arrow', 'none'
    .add_yaxis("商家B", v2,is_selected = True,symbol_size = 30)
    .set_global_opts(
            visualmap_opts=opts.VisualMapOpts(type_="color", max_=150, min_=20)  #  # 映射过渡类型，可选，"color", "size"
        )
    )
    
sca1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="15ba1909d97343eeb5968c5300a70076" style="width:1000px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_15ba1909d97343eeb5968c5300a70076 = echarts.init(
#                     document.getElementById('15ba1909d97343eeb5968c5300a70076'), 'white', {renderer: 'canvas'});
#                 var option_15ba1909d97343eeb5968c5300a70076 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
# 日历图
import datetime
import random
from pyecharts.charts import Calendar

begin = datetime.date(2017, 1, 1)
end = datetime.date(2017, 12, 31)
data = [
        [str(begin + datetime.timedelta(days=i)), random.randint(1000, 25000)]
        for i in range((end - begin).days + 1)
    ]
    
c = (
        Calendar()
        .add("", data, calendar_opts=opts.CalendarOpts(range_="2017"))
        .set_global_opts(
            visualmap_opts=opts.VisualMapOpts(
                max_=20000,
                min_=500,
                orient="horizontal",
                is_piecewise=True,
                pos_top="230px",
                pos_left="100px",
            ),
        )
    )
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1fa2bce3da8749ba90871c2aacb8cb2e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1fa2bce3da8749ba90871c2aacb8cb2e = echarts.init(
#                     document.getElementById('1fa2bce3da8749ba90871c2aacb8cb2e'), 'white', {renderer: 'canvas'});
#                 var option_1fa2bce3da8749ba90871c2aacb8cb2e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
import pyecharts

# %%
pyecharts.__version__
# Out:
# '1.9.1'

# %%
from pyecharts import *

# %%
from pyecharts import online
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-25-e3d7fa64611a> in <module>
# ----> 1 from pyecharts import online
#
# ImportError: cannot import name 'online' from 'pyecharts' (/Users/caixiaodan/anaconda/anaconda3/lib/python3.8/site-packages/pyecharts/__init__.py)

# %%
from pyecharts import WordCloud  # 导入词云模块
from jieba import analyse  # 从 jieba 中导入关键词分析模块

data = pd.read_csv("./iris.csv")
keyWords = analyse.extract_tags(sentence=data, # 要分词的任意一篇中文文章
                                topK=300,  # 300 个关键词
                                withWeight=True  # 显示每一个分词所占的权重
                                )  
print('>>>', keyWords[:10])
name, values = [], []
for key, weight in keyWords:
    name.append(key)
    values.append(weight)

wordcloud=WordCloud('0、词云图', width=1000, height=620)
wordcloud.add('', name, values, word_size_range=[20,100], is_more_utils=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-27-8faf3def225e> in <module>
# ----> 1 from pyecharts import WordCloud  # 导入词云模块
#       2 from jieba import analyse  # 从 jieba 中导入关键词分析模块
#       3
#       4 data = pd.read_csv("./iris.csv")
#       5 keyWords = analyse.extract_tags(sentence=data, # 要分词的任意一篇中文文章
#
# ImportError: cannot import name 'WordCloud' from 'pyecharts' (/Users/caixiaodan/anaconda/anaconda3/lib/python3.8/site-packages/pyecharts/__init__.py)

# %%
from pyecharts import Bar

labels = ['语文', '数学', '英语', '物理', '化学', '生物']
cj1 = [120, 147, 66, 94, 89, 95]
cj2 = [102, 145, 108, 87, 81, 89]
cj3 = [109, 126, 123, 90, 71, 82]

bar = Bar('1-1、纵向不堆叠柱状图', '副标题')
bar.add('学生A', labels, cj1, is_stack=False, is_more_utils=False)
bar.add('学生B', labels, cj2, is_stack=False, is_more_utils=False)

bar.add('学生C', labels, cj3, 
        is_stack=False,  # 是否堆叠柱形图
        is_more_utils=False  # 是否展示更多的工具
        )from pyecharts import Pie

labels = ['语文', '数学', '英语', '物理', '化学', '生物']
cj1 = [120, 134, 66, 94, 89, 95]
cj2 = [102, 129, 108, 87, 81, 89]

pie = Pie('2-1、单个饼图', '副标题')
pie.add('', labels, cj1, is_label_show=True)
pie.render()
pie

bar.render('/home/kesci/work/1-1.html')  # 将图形以网页形式保存在工作区
bar
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-28-468f2a9b7198> in <module>
# ----> 1 from pyecharts import Bar
#       2
#       3 labels = ['语文', '数学', '英语', '物理', '化学', '生物']
#       4 cj1 = [120, 147, 66, 94, 89, 95]
#       5 cj2 = [102, 145, 108, 87, 81, 89]
#
# ImportError: cannot import name 'Bar' from 'pyecharts' (/Users/caixiaodan/anaconda/anaconda3/lib/python3.8/site-packages/pyecharts/__init__.py)

# %%
from pyecharts import Pie

labels = ['语文', '数学', '英语', '物理', '化学', '生物']
cj1 = [120, 134, 66, 94, 89, 95]
cj2 = [102, 129, 108, 87, 81, 89]

pie = Pie('2-1、单个饼图', '副标题')
pie.add('', labels, cj1, is_label_show=True)
pie.render()
pie
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-29-4df712f11e48> in <module>
# ----> 1 from pyecharts import Pie
#       2
#       3 labels = ['语文', '数学', '英语', '物理', '化学', '生物']
#       4 cj1 = [120, 134, 66, 94, 89, 95]
#       5 cj2 = [102, 129, 108, 87, 81, 89]
#
# ImportError: cannot import name 'Pie' from 'pyecharts' (/Users/caixiaodan/anaconda/anaconda3/lib/python3.8/site-packages/pyecharts/__init__.py)

# %%
from pyecharts import Line

labels = ['A', 'B', 'C', 'D', 'F']
L1 = [73, 99, 54, 81, 243]
L2 = [-290, 210, 128, -200, 267]
L3 = [-78, -27, -81, -243, -300]
line = Line('3-1、普通折线图', '副标题', width=1000, height=400)
line.add('正数', labels, L1, is_smooth=True) 
line.render()
line
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-30-5c6cbbe463d4> in <module>
# ----> 1 from pyecharts import Line
#       2
#       3 labels = ['A', 'B', 'C', 'D', 'F']
#       4 L1 = [73, 99, 54, 81, 243]
#       5 L2 = [-290, 210, 128, -200, 267]
#
# ImportError: cannot import name 'Line' from 'pyecharts' (/Users/caixiaodan/anaconda/anaconda3/lib/python3.8/site-packages/pyecharts/__init__.py)

# %%
from pyecharts import Grid
from pyecharts import Line
from pyecharts import Bar

def gridPlot(selection=None):
        
    labels = ['语文', '数学', '英语', '物理', '化学', '生物']
    cj1 = [120, 147, 66, 94, 89, 95]
    cj2 = [-120, -147, -66, -94, -89, -95]

    line = Line("8-2、Line - Bar 组合图", '副标题', width=1000)
    line.add("line" , labels, cj1, is_more_utils=True, legend_pos='4%')
    line.add("line" , labels, cj2, is_more_utils=True)

    bar = Bar()
    bar.add("bar", labels, cj1, is_more_utils=True, legend_pos='70%')
    bar.add('bar', labels, cj2, legend_pos='70%')

    grid=Grid()
    grid.add(line,grid_right='60%')
    grid.add(bar,grid_left='50%')
    grid.render()  
    return grid

gridPlot()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-31-0d2119e1c85f> in <module>
# ----> 1 from pyecharts import Grid
#       2 from pyecharts import Line
#       3 from pyecharts import Bar
#       4
#       5 def gridPlot(selection=None):
#
# ImportError: cannot import name 'Grid' from 'pyecharts' (/Users/caixiaodan/anaconda/anaconda3/lib/python3.8/site-packages/pyecharts/__init__.py)

# %%
from pyecharts import Graph

# -----------------------------------------
# 节点
nodes = [{"name": "结点1", "symbolSize": 10},
         {"name": "结点2", "symbolSize": 8},
         {"name": "结点3", "symbolSize": 6},
         {"name": "结点4", "symbolSize": 7},
         {"name": "结点5", "symbolSize": 15},
         {"name": "结点6", "symbolSize": 3},
         {"name": "结点7", "symbolSize": 0},
         {"name": "结点8", "symbolSize": 0}]

# -----------------------------------------
# 节点之间的联系
links = []
for i in nodes:
    for j in nodes:
        links.append({"source": i.get('name'), "target": j.get('name')})
print(links[:5])

graph = Graph("关系图示例")
graph.add("", nodes, links, repulsion=1000, graph_layout='circular', is_label_show=True)
graph
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-32-48e75e15029c> in <module>
# ----> 1 from pyecharts import Graph
#       2
#       3 # -----------------------------------------
#       4 # 节点
#       5 nodes = [{"name": "结点1", "symbolSize": 10},
#
# ImportError: cannot import name 'Graph' from 'pyecharts' (/Users/caixiaodan/anaconda/anaconda3/lib/python3.8/site-packages/pyecharts/__init__.py)
