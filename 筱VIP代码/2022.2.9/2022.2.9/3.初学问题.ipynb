# %%
a = 1
_b = 2
    # 字母或者下划线开头
    # 不能数字开头
#print = 10
    # 不能用系统函数命名
#print(10)
print(a,_b)
# Out:
# 1 2

# %%
a1,b1 = 1,2
a2,b2 = '1','2'

print(a1+b1)
print(a2+b2)
# Out:
# 3
# 12

# %%
a1 * 10 #数字计算
a2 * 10 #字符串复制，重复
# Out:
# '1111111111'

# %%
lst = [1,2,3,4,5]#有顺序
dic = {'a1':1,'b1':2,'c1':'hello','d1':10}#依靠键值
    # []与{}
    # 顺序问题
print(lst)
print(dic)
# Out:
# [1, 2, 3, 4, 5]
# {'a1': 1, 'b1': 2, 'c1': 'hello', 'd1': 10}

# %%
lst = [10,20,30,40,50]
print(lst[0],lst[2],lst[-1])
# Out:
# 10 30 50

# %%
print(lst[1:2])#索引包前不包后
print(lst[:2])
print(lst[1:])
print(lst[::2])#步长
# Out:
# [20]
# [10, 20]
# [20, 30, 40, 50]
# [10, 30, 50]

# %%
dic = {'a1':1,'b1':2,'c1':'hello','d1':10}
for i in dic:#遍历的是键
    print(i)
# Out:
# a1
# b1
# c1
# d1

# %%
print(dic['a1'])
# Out:
# 1

# %%
lst = [1,2,3,4,5]
rg = range(5)#0,1,2,3,4
print(lst)
print(rg)
print(list(rg))
# Out:
# [1, 2, 3, 4, 5]
# range(0, 5)
# [0, 1, 2, 3, 4]

# %%
a = 1 #赋值
a  == 1 #布尔判断
# Out:
# True

# %%
n = 0
while n <10:
    print('hehehe')
    n += 1
#while n:#没有循环结束条件，死循环
    #print('hehehe')
    #n += 1
# Out:
# hehehe
# hehehe
# hehehe
# hehehe
# hehehe
# hehehe
# hehehe
# hehehe
# hehehe
# hehehe

# %%
def f1(x):
    print(x)

def f2(*x):# 默认会把可变参数传入一个元祖
    print(x)

f1(10)
f2(10,20,30)
# Out:
# 10
# (10, 20, 30)

# %%
def f3(x):
    a = x *10
    print(a)#打印输出
    
def f4(x):
    a = x *10
    return a #返回值
f3(10)
f4(10)
# Out:
# 100
# 100

# %%
import requests
from bs4 import BeautifulSoup

# %%
r = requests.get(url = 'https://market.douban.com/book/')
print(r.encoding, r.status_code, r.encoding)
print(r.url)
# Out:
# utf-8 200 utf-8
# https://market.douban.com/book/

# %%
#print(r.text)

# %%
soup = BeautifulSoup(r.text,'lxml')
#print(soup)

# %%
# 提取标签
#print(soup.head)  # 头部信息
print(soup.title) # 标题
print(soup.a)  # 提取的第一个a标签
# Out:
# <title>
#   豆瓣书店 - 新书
#   </title>
# <a class="nav-login" href="https://accounts.douban.com/passport/login?source=main" rel="nofollow">登录/注册</a>

# %%
print(type(soup.title))
print(type(soup.a))
# Out:
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>

# %%
print(soup.a.name,type(soup.a.name))
print(soup.a.attrs,type(soup.a.attrs))
print(soup.a.text,type(soup.a.text))
soup.a.attrs['href']
# Out:
# a <class 'str'>
# {'href': 'https://accounts.douban.com/passport/login?source=main', 'class': ['nav-login'], 'rel': ['nofollow']} <class 'dict'>
# 登录/注册 <class 'str'>
# 'https://accounts.douban.com/passport/login?source=main'

# %%
#查找标签
#test = soup.find('div',class_="grid-12-12 clearfix").find('a',class_='cover').attrs['href']
#test
test1 = soup.find_all()#查找所有标签
test1
# Out:
# [<html lang="zh-cmn-Hans">
#  <head>
#  <meta charset="utf-8"/>
#  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#  <meta content="豆瓣书店,活动" name="keywords"/>
#  <meta content="在豆瓣书店，遇见美好·書生活" name="description"/>
#  <meta content="https://market.douban.com/book" name="canonical"/>
#  <meta content="豆瓣书店" property="og:title"/>
#  <meta content="https://market.douban.com/book" property="og:url"/>
#  <meta content="https://img3.doubanio.com/f/freyr/6be0e452020b3e1f073ad12a6d2c0c8161fa18fb/pics/logo@2x.png" property="og:image"/>
#  <meta content="豆瓣书店" property="og:site_name"/>
#  <meta content="在豆瓣书店，遇见美好·書生活" property="og:description"/>
#  <link href="https://img3.doubanio.com/f/freyr/d076a5cecce1a0d01ad86a0419be060b0edf03d9/pc/base.css" rel="stylesheet" type="text/css"/>
#  <link href="//s.doubanio.com/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#  <title>
#    豆瓣书店 - 新书
#    </title>
#  <style>
# ...

# %%
#for url in urls[::2]:
    #url_lst.append(url['href'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-04b09f307f21> in <module>
# ----> 1 for url in urls[::2]:
#       2     url_lst.append(url['href'])
#
# NameError: name 'urls' is not defined

# %%
#创建函数，采集页面信息
def get_data(ui):
    ri = requests.get(url = ui)  
    soupi = BeautifulSoup(ri.text,'lxml')   
        # 访问页面 + 页面解析
    infors = soupi.find_all('div',class_="detail-frame")
    lst = []
    for i in infors:
        dic = {}
        dic['书名'] = i.find('h2').text.replace('\n','')
        dic['评分'] = i.find_all('p')[0].text.replace('\n','').replace(' ','')
        dic['其他信息'] = i.find_all('p')[1].text.replace('\n','').replace(' ','')
        dic['简介'] = i.find_all('p')[2].text.replace('\n','').replace(' ','')
        lst.append(dic)
    return lst
    # 函数构建完成

url = 'https://market.douban.com/book/'
result = get_data(url)
    # 调用函数采集数据

result[:3]
# Out:
# []

# %%
import pandas as pd
df = pd.DataFrame(result)
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
f = open('/home/kesci/资料01_商铺数据.csv','r',encoding='utf-8')
for i in f.readlines()[:5]:
    print(i.split(','))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-68-940a6b3ba865> in <module>
#       1 f = open('./商机数据的副本.xlsx','r',encoding='utf-8')
# ----> 2 for i in f.readlines()[:5]:
#       3     print(i.split(','))
#
# ~/anaconda/anaconda3/lib/python3.8/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x87 in position 10: invalid start byte

# %%
def fpr(s):
    if '条' in s:
        return int (s.split(' ')[0])#空格分段
    else:
        return '确实数据'
    #选取列表结果的第一个值为点评数
def fpr(s):
    if '￥' in s:
        return float(s.split('￥')[-1])
    else:
        return '缺失数据'
    #用¥分段，选取列表最后一个作为人均价格，并且转化为浮点型
def fcl(s):
    if ' ' in s:
        quality = float(s.split('              ')[0][2:])
        environment = float(s.split('          ')[1][2:])
        service = float(s.split('             ')[2][2:-1])
        return [quality,environment,service]
    else:
        return '缺失数据'

# %%
# 数据清洗

datalst = []  # 创建空列表

f.seek(0)
n = 0  # 创建计数变量
for i in f.readlines():
    data = i.split(',')
    #print(data)
    classify = data[0]             # 提取分类
    name = data[1]                 # 提取店铺名称
    comment_count = fcm(data[2])   # 提取评论数量
    star = data[3]                 # 提取星级
    price = fpr(data[4])           # 提取人均
    add = data[5]                  # 提取地址
    qua = fcl(data[6])[0]          # 提取质量评分
    env = fcl(data[6])[1]          # 提取环境评分
    ser = fcl(data[6])[2]          # 提取服务评分
    if  '缺失数据' not in [comment_count, price, qua]:   # 用于判断是否有数据缺失
        n += 1
        data_re = [['classify',classify],
                  ['name',name],
                  ['comment_count',comment_count],
                  ['star',star],
                  ['price',price],
                  ['address',add],
                  ['quality',qua],
                  ['environment',env],
                  ['service',ser]]
        datalst.append(dict(data_re))   # 生成字典，并存入列表datalst
        #print('成功加载%i条数据' %n)
    else:
        continue
    
print(datalst[:10]) 
print('总共加载%i条数据' %n)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-70-890ac4e4956b> in <module>
#       5 f.seek(0)
#       6 n = 0  # 创建计数变量
# ----> 7 for i in f.readlines():
#       8     data = i.split(',')
#       9     #print(data)
#
# ~/anaconda/anaconda3/lib/python3.8/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x87 in position 10: invalid start byte

# %%
datalst = []
f.seek(0)
n = 0
for i in f.readlines():
    data = i.split(',')
    classify = data[0]
    name = data[1]
    comment_count = fcm(data[2])
    star = data[3]
    price = fpr(data[4])
    add = data[5]
    qua = fcl(dat[6])[0]
    env = fcl(data[6])[1]
    ser = fcl(data[6])[2]
    if '缺失数据' not in [comment_count,price,qua]:
        n += 1
        data_re = [['classify',classify],
                  ['name',name],
                  ['comment_count',comment_count],
                  ['star',star],
                  ['price',price],
                  ['address',add],
                  ['quality',qua],
                  ['environment',env],
                  ['service',ser]]
        datalst.append(dict(data_re))#生成字典
    else:
        continue
        
print(datalst[:10])
print('共加载%si条数据'%n)
